# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('weather_2012.csv')

# %%
df.head(5)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.tail(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
df.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 7087  2012-10-22 07:00:00       7.8                 4.4           79
# 3249  2012-05-15 09:00:00      18.7                14.5           77
# 8507  2012-12-20 11:00:00      -1.1                -4.0           81
# 5659  2012-08-23 19:00:00      22.6                15.8           65
# 548   2012-01-23 20:00:00       2.9                 1.2           89
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 7087               15             24.1           101.00  Mainly Clear
# 3249                9             24.1           101.20        Cloudy
# 8507                4             24.1           101.92          Snow
# 5659                9             25.0           101.36  Mainly Clear
# 548                26              9.7           100.32   Drizzle,Fog

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
df.rename(columns={
    'Date/Time': 'date_time',
    'Temp (C)': 'temp_c',
    'Dew Point Temp (C)': 'dew_point',
    'Rel Hum (%)': 'relative_humidity',
    'Wind Spd (km/h)': 'wind_speed',
    'Visibility (km)': 'visibility',
    'Stn Press (kPa)': 'pressure',
    'Weather': 'weather'
}, inplace=True)

# %%
df
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather
# ...

# %%
def Temp(celsius):
    return (celsius * 9/5) + 32

df['temp_f']=df['temp_c'].apply(Temp)

# %%
df
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather  temp_f
# ...

# %%
desired_columns=['temp_f', 'temp_c'] + [col for col in df.columns if col not in ['temp_f','temp_c']]
df = df[desired_columns]

# %%
df
# Out:
#       temp_f  temp_c            date_time  dew_point  relative_humidity  \
# 0      28.76    -1.8  2012-01-01 00:00:00       -3.9                 86
# 1      28.76    -1.8  2012-01-01 01:00:00       -3.7                 87
# 2      28.76    -1.8  2012-01-01 02:00:00       -3.4                 89
# 3      29.30    -1.5  2012-01-01 03:00:00       -3.2                 88
# 4      29.30    -1.5  2012-01-01 04:00:00       -3.3                 88
# ...      ...     ...                  ...        ...                ...
# 8779   32.18     0.1  2012-12-31 19:00:00       -2.7                 81
# 8780   32.36     0.2  2012-12-31 20:00:00       -2.4                 83
# 8781   31.10    -0.5  2012-12-31 21:00:00       -1.5                 93
# 8782   31.64    -0.2  2012-12-31 22:00:00       -1.8                 89
# 8783   32.00     0.0  2012-12-31 23:00:00       -2.1                 86
#
#       wind_speed  visibility  pressure               weather
# ...

# %%
df.columns
# Out:
# Index(['temp_f', 'temp_c', 'date_time', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temp_f             8784 non-null   float64
#  1   temp_c             8784 non-null   float64
#  2   date_time          8784 non-null   object
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 617.8+ KB

# %%
df['date_time']=pd.to_datetime(df['date_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temp_f             8784 non-null   float64
#  1   temp_c             8784 non-null   float64
#  2   date_time          8784 non-null   datetime64[ns]
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 617.8+ KB

# %%
df['weather'].nunique()
# Out:
# 50

# %%
df['weather'].unique()[0:10]
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['temp_f', 'temp_c', 'date_time', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather'],
#       dtype='object')

# %%
df_list=df.query('temp_f>90 & relative_humidity<50 & dew_point>17 & weather=="Clear"')

# %%
df_list.to_csv('df_list.csv', index=False)

# %%
df_list=pd.read_csv('df_list.csv')
df_list
# Out:
#    temp_f  temp_c            date_time  dew_point  relative_humidity  \
# 0   91.04    32.8  2012-08-04 15:00:00       18.8                 44
# 1   90.50    32.5  2012-08-04 16:00:00       18.5                 44
# 2   90.50    32.5  2012-08-04 17:00:00       19.8                 47
#
#    wind_speed  visibility  pressure weather
# 0          17        24.1    101.39   Clear
# 1          15        24.1    101.34   Clear
# 2          13        24.1    101.32   Clear

# %%
df['month'] = df['date_time'].dt.month

# %%
df
# Out:
#       temp_f  temp_c           date_time  dew_point  relative_humidity  \
# 0      28.76    -1.8 2012-01-01 00:00:00       -3.9                 86
# 1      28.76    -1.8 2012-01-01 01:00:00       -3.7                 87
# 2      28.76    -1.8 2012-01-01 02:00:00       -3.4                 89
# 3      29.30    -1.5 2012-01-01 03:00:00       -3.2                 88
# 4      29.30    -1.5 2012-01-01 04:00:00       -3.3                 88
# ...      ...     ...                 ...        ...                ...
# 8779   32.18     0.1 2012-12-31 19:00:00       -2.7                 81
# 8780   32.36     0.2 2012-12-31 20:00:00       -2.4                 83
# 8781   31.10    -0.5 2012-12-31 21:00:00       -1.5                 93
# 8782   31.64    -0.2 2012-12-31 22:00:00       -1.8                 89
# 8783   32.00     0.0 2012-12-31 23:00:00       -2.1                 86
#
#       wind_speed  visibility  pressure               weather  month
# ...

# %%
df.to_csv('weather_2012_new.csv',index=False)

# %%
df=pd.read_csv('weather_2012_new.csv',index_col=[0])
df.sample(2)
# Out:
#         temp_c            date_time  dew_point  relative_humidity  wind_speed  \
# temp_f
# 36.86      2.7  2012-02-09 16:00:00       -6.5                 51          22
# 64.94     18.3  2012-08-18 10:00:00       11.6                 65          17
#
#         visibility  pressure        weather  month
# temp_f
# 36.86         48.3    101.01          Clear      2
# 64.94         24.1    100.83  Mostly Cloudy      8
